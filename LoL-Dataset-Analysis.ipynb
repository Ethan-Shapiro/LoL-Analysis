# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("high_diamond_ranked_10min.csv")

# %% [markdown]
# Data set contains various in game metrics pertaining to each team and if blue or red team won

# %%
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
df.describe()
# Out:
#              gameId     blueWins  blueWardsPlaced  blueWardsDestroyed  \
# count  9.879000e+03  9879.000000      9879.000000         9879.000000
# mean   4.500084e+09     0.499038        22.288288            2.824881
# std    2.757328e+07     0.500024        18.019177            2.174998
# min    4.295358e+09     0.000000         5.000000            0.000000
# 25%    4.483301e+09     0.000000        14.000000            1.000000
# 50%    4.510920e+09     0.000000        16.000000            3.000000
# 75%    4.521733e+09     1.000000        20.000000            4.000000
# max    4.527991e+09     1.000000       250.000000           27.000000
#
#        blueFirstBlood    blueKills   blueDeaths  blueAssists  \
# count     9879.000000  9879.000000  9879.000000  9879.000000
# mean         0.504808     6.183925     6.137666     6.645106
# std          0.500002     3.011028     2.933818     4.064520
# min          0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# Check for Missing (No Missing Values Yayy)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gameId                        9879 non-null   int64
#  1   blueWins                      9879 non-null   int64
#  2   blueWardsPlaced               9879 non-null   int64
#  3   blueWardsDestroyed            9879 non-null   int64
#  4   blueFirstBlood                9879 non-null   int64
#  5   blueKills                     9879 non-null   int64
#  6   blueDeaths                    9879 non-null   int64
#  7   blueAssists                   9879 non-null   int64
#  8   blueEliteMonsters             9879 non-null   int64
#  9   blueDragons                   9879 non-null   int64
#  10  blueHeralds                   9879 non-null   int64
#  11  blueTowersDestroyed           9879 non-null   int64
#  12  blueTotalGold                 9879 non-null   int64
# ...

# %% [markdown]
# <h1>EDA</h1>

# %% [markdown]
# <p>Firstly, let's understand what each attribute means</p>
# <ol>
#     <li><b>Wards</b> - Wards can be placed by players to reveal areas of the map that were previously dark. They can be destryoed using various items in the game </li>
#     <li><b>First Blood</b> - First bloods contribute 400 gold to player(s), giving the player a lead from the start</li>
#     <li><b>KDA</b> - How many times a player was killed/dead or players asissted in killing the enemy.</li>
#     <li><b>Dragons</b> - Dragons give powerful buffs to the team which slays them and therefore have a lot of influence over the outcome of the game.</li>
#     <li><b>Towers Destroyed</b> - Destroying a tower opens up the map to allow the team to move into more areas.</li>
#     <li><b>Gold</b> - Having more gold than your opponent allows you to buy more items and therefore be more powerful.</li>
#     <li><b>Experience</b> - The more experience someone has, the higher the level and more powerful they are.</li>
# </ol>
# <p>Now that we have a general understanding of each feature and its affect on the outcome of the game, let's look into each teams metrics<p>

# %%
# We have an even data set woooh!
sns.countplot(x=df['blueWins'])
plt.show()
print(df['blueWins'].value_counts())
# Out:
# 0    4949
# 1    4930
# Name: blueWins, dtype: int64

# %%
#Drop repeated columns (Red Deaths = Blue Kills, )
cols = ['redHeralds', 'redDragons', 'redGoldDiff', 'redExperienceDiff', 'blueCSPerMin', 'redCSPerMin', 'blueGoldPerMin',
        'redGoldPerMin', 'redTotalMinionsKilled', 'blueTotalMinionsKilled', 'redKills', 'redDeaths', 
        'redFirstBlood', 'redWardsDestroyed', 'gameId']

df_clean = df.drop(cols, axis=1)
df_clean.columns
# Out:
# Index(['blueWins', 'blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood',
#        'blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters',
#        'blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold',
#        'blueAvgLevel', 'blueTotalExperience', 'blueTotalJungleMinionsKilled',
#        'blueGoldDiff', 'blueExperienceDiff', 'redWardsPlaced', 'redAssists',
#        'redEliteMonsters', 'redTowersDestroyed', 'redTotalGold', 'redAvgLevel',
#        'redTotalExperience', 'redTotalJungleMinionsKilled'],
#       dtype='object')

# %%
plt.figure(figsize=(18, 14))
sns.heatmap(df_clean.corr(), cmap='YlGnBu', annot=True, fmt='.2f', vmin=0)

# %%
# Remove features with high colinearity
cols = ['blueTotalGold', 'blueAssists', 'redTotalGold', 'redTotalExperience', 'redAvgLevel', 'redAssists', 
        'blueAvgLevel', 'blueAvgLevel']
df_clean = df_clean.drop(cols, axis=1)

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df_clean.corr(), cmap='YlGnBu', annot=True, fmt='.2f', vmin=0)

# %%
# Remove features that don't have a correlation with the target, blueWins
corr = df_clean.corr()['blueWins'][1:]
target = df_clean['blueWins']
i = 1
cols = []
for c in corr:
    if c < -.2 or c > .2:
        print(c)
        print(df_clean.columns[i])
        cols.append(df_clean.columns[i])
    i += 1

df_clean = df_clean.loc[:, cols]
# Out:
# 0.201769264385699
# blueFirstBlood
# 0.3373576105342249
# blueKills
# -0.33929674108756996
# blueDeaths
# 0.2219441945274097
# blueEliteMonsters
# 0.21376769276292393
# blueDragons
# 0.3961407056514206
# blueTotalExperience
# 0.5111190551762275
# blueGoldDiff
# 0.48955791655967607
# blueExperienceDiff
# -0.22155108781856242
# redEliteMonsters

# %%
df_clean.columns
# Out:
# Index(['blueFirstBlood', 'blueKills', 'blueDeaths', 'blueEliteMonsters',
#        'blueDragons', 'blueTotalExperience', 'blueGoldDiff',
#        'blueExperienceDiff', 'redEliteMonsters'],
#       dtype='object')

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(pd.concat([df_clean, df['blueWins']], axis=1).corr(), cmap='YlGnBu', annot=True, fmt='.2f', vmin=0)
plt.show()

# %%
# Remove two variables with lower correlation to blueWins to reduce colinearity
df_clean = df_clean.drop(['blueTotalExperience', 'blueExperienceDiff'], axis=1)

# %%
df_clean.hist(alpha=.7, bins=5, figsize=(12, 10))
plt.show()

# %%
ax = sns.PairGrid(pd.concat([df_clean, target], axis=1), 
                  vars=['blueGoldDiff', 'blueKills', 'blueDeaths'],
                  hue='blueWins', palette='Set1')
ax.map_diag(plt.hist)
ax.map_offdiag(plt.scatter)
handles = ax._legend_data.values()
labels = ax._legend_data.keys()
ax.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=1)
plt.show()

# %% [markdown]
# <h1>Model Selection</h1>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

X = df_clean
y = target

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# <h3>Naive Bayes</h3>

# %%
from sklearn.naive_bayes import GaussianNB

bayes = GaussianNB()

bayes.fit(X_train, y_train)
pred = bayes.predict(X_test)

print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.718491260349586
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      1624
#            1       0.72      0.72      0.72      1637
#
#     accuracy                           0.72      3261
#    macro avg       0.72      0.72      0.72      3261
# weighted avg       0.72      0.72      0.72      3261

# %% [markdown]
# <h3>Decision Tree</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dt = DecisionTreeClassifier()

# search the best params
grid = {'min_samples_split': [5, 10, 20, 50, 100], 'max_leaf_nodes': [10, 50, 100], 'criterion': ['gini', 'entropy']}

grid_tree = GridSearchCV(dt, grid, cv=5)
grid_tree.fit(X_train, y_train)

pred = grid_tree.predict(X_test)

print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.7209444955535111
#               precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74      1624
#            1       0.76      0.65      0.70      1637
#
#     accuracy                           0.72      3261
#    macro avg       0.73      0.72      0.72      3261
# weighted avg       0.73      0.72      0.72      3261

# %% [markdown]
# <h3>Random Forest</h3>

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

grid = {'criterion': ['gini', 'entropy'], 'max_depth': [2, 5, 10], 'n_estimators': [100, 250, 500]}

grid_rf = GridSearchCV(rf, grid, cv=5)
grid_rf.fit(X_train, y_train)

pred = grid_rf.predict(X_test)

print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.7215578043544925
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73      1624
#            1       0.73      0.70      0.72      1637
#
#     accuracy                           0.72      3261
#    macro avg       0.72      0.72      0.72      3261
# weighted avg       0.72      0.72      0.72      3261

# %% [markdown]
# <h3>Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression

lm = LogisticRegression()

lm.fit(X_train, y_train)

pred = lm.predict(X_test)

print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.7322907083716651
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      1624
#            1       0.73      0.73      0.73      1637
#
#     accuracy                           0.73      3261
#    macro avg       0.73      0.73      0.73      3261
# weighted avg       0.73      0.73      0.73      3261

# %% [markdown]
# <h3>K-nearest Neighbors</h3>

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

grid = {'n_neighbors': np.arange(1, 50)}
grid_knn = GridSearchCV(knn, grid, cv=5)
grid_knn.fit(X_train, y_train)

pred = grid_knn.predict(X_test)

print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.7200245323520392
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72      1624
#            1       0.73      0.71      0.72      1637
#
#     accuracy                           0.72      3261
#    macro avg       0.72      0.72      0.72      3261
# weighted avg       0.72      0.72      0.72      3261

# %% [markdown]
# Logistic regression achieved the best scores. Let's do some PCA to try and improve the scores

# %% [markdown]
# <h2>PCA</h2>

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

components = pca.fit_transform(X)
print(pca.explained_variance_ratio_)
# Out:
# [0.4081232  0.21136298]

# %%
df_pca = pd.DataFrame(components, columns=['pc1', 'pc2'])
df_pca = pd.concat([df_pca, df['blueWins']], axis=1)

X = df_pca.drop('blueWins', axis=1)
y = df_pca['blueWins']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
lm.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = lm.predict(X_test)

print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.7154247163446795
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71      1624
#            1       0.72      0.72      0.72      1637
#
#     accuracy                           0.72      3261
#    macro avg       0.72      0.72      0.72      3261
# weighted avg       0.72      0.72      0.72      3261
